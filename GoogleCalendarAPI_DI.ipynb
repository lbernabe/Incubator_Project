# %%
from datetime import datetime

import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials

#mathematical operations on lists
import numpy as np

#store the data we get as a dataframe
import pandas as pd

# %% [markdown]
# # Credential process

# %%
# If modifying these scopes, delete the file token.json.
#SCOPES = ['https://www.googleapis.com/auth/calendar.readonly']
SCOPES = ['https://www.googleapis.com/auth/calendar']

# %%
#Credential process
creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
if os.path.exists('google_token.json'):
    creds = Credentials.from_authorized_user_file('google_token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'googlecalendar_credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('google_token.json', 'w') as token:
        token.write(creds.to_json())

# %% [markdown]
# # Call calendar API

# %%
service = build('calendar', 'v3', credentials=creds)

# Call the Calendar API
now = datetime.utcnow().isoformat() + 'Z' # 'Z' indicates UTC time
print('Getting the upcoming 10 events')
events_result = service.events().list(calendarId='primary', timeMin=now,
                                        maxResults=10, singleEvents=True,
                                        orderBy='startTime').execute()
events = events_result.get('items', [])
# Out:
# Getting the upcoming 10 events

# %%
# Events is a 
type(events)
# Out:
# list

# %%
events
# Out:
# [{'kind': 'calendar#event',
#   'etag': '"3239652716944000"',
#   'id': '04uh3qlenehpd927mtg9i8m0t0',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MDR1aDNxbGVuZWhwZDkyN210ZzlpOG0wdDAgbGF1cmEuYmVybmFiZS5taWd1ZWxAbQ',
#   'created': '2021-04-30T23:45:58.000Z',
#   'updated': '2021-04-30T23:45:58.472Z',
#   'summary': 'Llega LuisMiguel',
#   'creator': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'organizer': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'start': {'date': '2021-05-06'},
#   'end': {'date': '2021-05-07'},
#   'transparency': 'transparent',
#   'iCalUID': '04uh3qlenehpd927mtg9i8m0t0@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': False,
#    'overrides': [{'method': 'popup', 'minutes': 10},
#     {'method': 'email', 'minutes': 430}]},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3239607654722000"',
#   'id': '02c7e2e36ach9e1shm35uldcmd',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MDJjN2UyZTM2YWNoOWUxc2htMzV1bGRjbWQgbGF1cmEuYmVybmFiZS5taWd1ZWxAbQ',
#   'created': '2021-04-28T20:34:52.000Z',
#   'updated': '2021-04-30T17:30:27.361Z',
#   'summary': 'TDI Admissions Interview',
#   'description': '- The interview will take place in a group setting with 3–5 other applicants.\xa0<br>- Interviews will take approximately 1 hour<br>- You will have 2-3 minutes to share your proposal<br>- Be prepared to share a link to your work for the group to use to follow along\xa0<br>- The\xa0<b>zoom link\xa0</b>will appear in your\xa0<a href="https://www.thedataincubator.com/fellowship/application_status.html" target="_blank">dashboard</a>\xa0<b>30 minutes</b>\xa0prior to your scheduled time',
#   'location': 'https://www.thedataincubator.com/fellowship/application_status.html',
#   'creator': {'email': 'administrator@thedataincubator.com'},
#   'organizer': {'email': 'administrator@thedataincubator.com'},
#   'start': {'dateTime': '2021-05-06T11:00:00-06:00'},
#   'end': {'dateTime': '2021-05-06T12:00:00-06:00'},
#   'iCalUID': '02c7e2e36ach9e1shm35uldcmd@google.com',
#   'sequence': 0,
#   'attendees': [{'email': 'laura.bernabe.miguel@gmail.com',
#     'self': True,
#     'responseStatus': 'needsAction'}],
#   'guestsCanInviteOthers': False,
#   'guestsCanSeeOtherGuests': False,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3240313055156000"',
#   'id': '34h0lvcj3ohuo4vpg5dv5bs18n',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MzRoMGx2Y2ozb2h1bzR2cGc1ZHY1YnMxOG4gbGF1cmEuYmVybmFiZS5taWd1ZWxAbQ',
#   'created': '2021-05-04T19:28:14.000Z',
#   'updated': '2021-05-04T19:28:47.578Z',
#   'summary': '2:30 pm Barbara ',
#   'description': '<u>Red Dot Storage</u>',
#   'creator': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'organizer': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'start': {'dateTime': '2021-05-06T14:30:00-06:00'},
#   'end': {'dateTime': '2021-05-06T15:30:00-06:00'},
#   'iCalUID': '34h0lvcj3ohuo4vpg5dv5bs18n@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3237084390974000"',
#   'id': '09ml3jhge82bvbri3liiu3cthn',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MDltbDNqaGdlODJidmJyaTNsaWl1M2N0aG4gbGF1cmEuYmVybmFiZS5taWd1ZWxAbQ',
#   'created': '2021-04-16T01:33:57.000Z',
#   'updated': '2021-04-16T03:03:15.487Z',
#   'summary': 'Laura Bernabé SEI Follow-Up Schedule Interview? ',
#   'creator': {'email': 'alec.nichols@generalassemb.ly'},
#   'organizer': {'email': 'alec.nichols@generalassemb.ly'},
#   'start': {'dateTime': '2021-05-06T16:30:00-06:00'},
#   'end': {'dateTime': '2021-05-06T17:00:00-06:00'},
#   'iCalUID': '09ml3jhge82bvbri3liiu3cthn@google.com',
#   'sequence': 0,
#   'attendees': [{'email': 'laura.bernabe.miguel@gmail.com',
#     'self': True,
#     'responseStatus': 'accepted'},
#    {'email': 'alec.nichols@generalassemb.ly',
#     'organizer': True,
#     'responseStatus': 'accepted'}],
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3240312900328000"',
#   'id': 'tmub675b52smet45d9u3tdve9g',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=dG11YjY3NWI1MnNtZXQ0NWQ5dTN0ZHZlOWcgbGF1cmEuYmVybmFiZS5taWd1ZWxAbQ',
#   'created': '2021-05-01T22:52:50.000Z',
#   'updated': '2021-05-04T19:27:30.164Z',
#   'summary': 'Laura Bernabe Miguel and Jessica Nerad',
#   'description': 'Event Name: Quick 20 - 25 Minute Chat!<br><br>Call me at 816-729-4497 when you are ready!<br><br>Location: +1 816-729-4497<br><br>Please share anything that will help prepare for our meeting.: Understand what are the requirements of this position and if I am good good for it.<br><br>Need to make changes to this event?<br>Cancel: <a href="https://calendly.com/cancellations/GE75QRBIS73VVFKX">https://calendly.com/cancellations/GE75QRBIS73VVFKX</a><br>Reschedule: <a href="https://calendly.com/reschedulings/GE75QRBIS73VVFKX">https://calendly.com/reschedulings/GE75QRBIS73VVFKX</a><br><br>Powered by Calendly.com<br><br>SOVRn software engineer',
#   'location': '+1 816-729-4497',
#   'creator': {'email': 'jessica@alignhr.net'},
#   'organizer': {'email': 'jessica@alignhr.net'},
#   'start': {'dateTime': '2021-05-07T09:15:00-06:00'},
#   'end': {'dateTime': '2021-05-07T09:45:00-06:00'},
#   'iCalUID': 'tmub675b52smet45d9u3tdve9g@google.com',
#   'sequence': 0,
#   'attendees': [{'email': 'jessica@alignhr.net',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'laura.bernabe.miguel@gmail.com',
#     'self': True,
#     'responseStatus': 'accepted'}],
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3240312774934000"',
#   'id': '5ghcencou6ltardrs6mf1qb5o5',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NWdoY2VuY291Nmx0YXJkcnM2bWYxcWI1bzUgbGF1cmEuYmVybmFiZS5taWd1ZWxAbQ',
#   'created': '2021-05-04T19:26:06.000Z',
#   'updated': '2021-05-04T19:26:27.467Z',
#   'summary': 'Liam Scott',
#   'description': ' ITmPowered Consulting',
#   'creator': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'organizer': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'start': {'dateTime': '2021-05-07T14:00:00-06:00'},
#   'end': {'dateTime': '2021-05-07T15:00:00-06:00'},
#   'iCalUID': '5ghcencou6ltardrs6mf1qb5o5@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3240482939868000"',
#   'id': '652j0it1no5th69ma33nkisvlb',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NjUyajBpdDFubzV0aDY5bWEzM25raXN2bGIgbGF1cmEuYmVybmFiZS5taWd1ZWxAbQ',
#   'created': '2021-05-05T19:04:29.000Z',
#   'updated': '2021-05-05T19:04:29.934Z',
#   'summary': 'refinance',
#   'creator': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'organizer': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'start': {'dateTime': '2021-05-08T08:00:00-06:00'},
#   'end': {'dateTime': '2021-05-08T09:00:00-06:00'},
#   'iCalUID': '652j0it1no5th69ma33nkisvlb@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3240482901542000"',
#   'id': '60clga1kp5ubq0gfq0nq5rrfbi',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NjBjbGdhMWtwNXVicTBnZnEwbnE1cnJmYmkgbGF1cmEuYmVybmFiZS5taWd1ZWxAbQ',
#   'created': '2021-05-05T19:04:10.000Z',
#   'updated': '2021-05-05T19:04:10.771Z',
#   'summary': 'flights',
#   'creator': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'organizer': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'start': {'dateTime': '2021-05-08T09:00:00-06:00'},
#   'end': {'dateTime': '2021-05-08T10:00:00-06:00'},
#   'iCalUID': '60clga1kp5ubq0gfq0nq5rrfbi@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3239295616502000"',
#   'id': '1npk9f5p9instat4pnl1cccrv1',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MW5wazlmNXA5aW5zdGF0NHBubDFjY2NydjEgbGF1cmEuYmVybmFiZS5taWd1ZWxAbQ',
#   'created': '2021-04-28T22:09:43.000Z',
#   'updated': '2021-04-28T22:10:08.251Z',
#   'summary': "Ward's BD",
#   'location': '1119 Gale Avenue in Boulder',
#   'creator': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'organizer': {'email': 'laura.bernabe.miguel@gmail.com', 'self': True},
#   'start': {'dateTime': '2021-05-08T12:00:00-06:00'},
#   'end': {'dateTime': '2021-05-08T13:00:00-06:00'},
#   'iCalUID': '1npk9f5p9instat4pnl1cccrv1@google.com',
#   'sequence': 0,
#   'reminders': {'useDefault': True},
#   'eventType': 'default'},
#  {'kind': 'calendar#event',
#   'etag': '"3235509616330000"',
#   'id': '17ejo1onoir2ltconlhq2m3kj6_20210510T020000Z',
#   'status': 'confirmed',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MTdlam8xb25vaXIybHRjb25saHEybTNrajZfMjAyMTA1MTBUMDIwMDAwWiBsYXVyYS5iZXJuYWJlLm1pZ3VlbEBt',
#   'created': '2021-01-14T02:16:36.000Z',
#   'updated': '2021-04-07T00:20:08.165Z',
#   'summary': 'Methin Around Chat',
#   'description': 'Just getting a weekly fb video call on the calendar. Whoever is free can join. If this time isn’t great for the majority, let’s change it!',
#   'creator': {'email': 'klellenwood@gmail.com'},
#   'organizer': {'email': 'klellenwood@gmail.com'},
#   'start': {'dateTime': '2021-05-09T20:00:00-06:00',
#    'timeZone': 'America/Denver'},
#   'end': {'dateTime': '2021-05-09T21:00:00-06:00',
#    'timeZone': 'America/Denver'},
#   'recurringEventId': '17ejo1onoir2ltconlhq2m3kj6',
#   'originalStartTime': {'dateTime': '2021-05-09T20:00:00-06:00',
#    'timeZone': 'America/Denver'},
#   'iCalUID': '17ejo1onoir2ltconlhq2m3kj6@google.com',
#   'sequence': 4,
#   'attendees': [{'email': 'rachel.vecchitto@gmail.com',
#     'responseStatus': 'needsAction'},
#    {'email': 'klellenwood@gmail.com',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'laura.bernabe.miguel@gmail.com',
#     'self': True,
#     'responseStatus': 'needsAction'},
#    {'email': 'emilyseagrave@gmail.com', 'responseStatus': 'accepted'},
#    {'email': 'demmilyday@gmail.com', 'responseStatus': 'needsAction'}],
#   'hangoutLink': 'https://meet.google.com/tbh-qaus-vtu',
#   'conferenceData': {'createRequest': {'requestId': 'jus868elnbqi2rkbfu19rhm73c',
#     'conferenceSolutionKey': {'type': 'hangoutsMeet'},
#     'status': {'statusCode': 'pending'}},
#    'entryPoints': [{'entryPointType': 'video',
#      'uri': 'https://meet.google.com/tbh-qaus-vtu',
#      'label': 'meet.google.com/tbh-qaus-vtu'}],
#    'conferenceSolution': {'key': {'type': 'hangoutsMeet'},
#     'name': 'Google Meet',
#     'iconUri': 'https://fonts.gstatic.com/s/i/productlogos/meet_2020q4/v6/web-512dp/logo_meet_2020q4_color_2x_web_512dp.png'},
#    'conferenceId': 'tbh-qaus-vtu',
#    'signature': 'ACn9hYGsBV2baTqZM6nNM3GP2UCf'},
#   'reminders': {'useDefault': True},
#   'eventType': 'default'}]

# %% [markdown]
# # Pandas manipulation

# %%
df_calendar= pd.DataFrame(events)

# %%
df_calendar.columns
# Out:
# Index(['attendees', 'conferenceData', 'created', 'creator', 'description',
#        'end', 'etag', 'eventType', 'guestsCanInviteOthers',
#        'guestsCanSeeOtherGuests', 'hangoutLink', 'htmlLink', 'iCalUID', 'id',
#        'kind', 'location', 'organizer', 'originalStartTime',
#        'recurringEventId', 'reminders', 'sequence', 'start', 'status',
#        'summary', 'transparency', 'updated'],
#       dtype='object')

# %%
df_calendar.drop(['attendees','creator'],1)
# Out:
#                                       conferenceData  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  {'createRequest': {'requestId': 'jus868elnbqi2...
#
#                     created  \
# 0  2021-04-30T23:45:58.000Z
# 1  2021-04-28T20:34:52.000Z
# 2  2021-05-04T19:28:14.000Z
# 3  2021-04-16T01:33:57.000Z
# 4  2021-05-01T22:52:50.000Z
# 5  2021-05-04T19:26:06.000Z
# 6  2021-05-05T19:04:29.000Z
# 7  2021-05-05T19:04:10.000Z
# 8  2021-04-28T22:09:43.000Z
# 9  2021-01-14T02:16:36.000Z
#
#                                          description  \
# 0                                                NaN
# 1  - The interview will take place in a group set...
# 2                             <u>Red Dot Storage</u>
# 3                                                NaN
# 4  Event Name: Quick 20 - 25 Minute Chat!<br><br>...
# 5                              ITmPowered Consulting
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Just getting a weekly fb video call on the cal...
#
#                                                  end                etag  \
# 0                             {'date': '2021-05-07'}  "3239652716944000"
# 1          {'dateTime': '2021-05-06T12:00:00-06:00'}  "3239607654722000"
# 2          {'dateTime': '2021-05-06T15:30:00-06:00'}  "3240313055156000"
# 3          {'dateTime': '2021-05-06T17:00:00-06:00'}  "3237084390974000"
# 4          {'dateTime': '2021-05-07T09:45:00-06:00'}  "3240312900328000"
# 5          {'dateTime': '2021-05-07T15:00:00-06:00'}  "3240312774934000"
# 6          {'dateTime': '2021-05-08T09:00:00-06:00'}  "3240482939868000"
# 7          {'dateTime': '2021-05-08T10:00:00-06:00'}  "3240482901542000"
# 8          {'dateTime': '2021-05-08T13:00:00-06:00'}  "3239295616502000"
# 9  {'dateTime': '2021-05-09T21:00:00-06:00', 'tim...  "3235509616330000"
#
#   eventType guestsCanInviteOthers guestsCanSeeOtherGuests  \
# 0   default                   NaN                     NaN
# 1   default                 False                   False
# 2   default                   NaN                     NaN
# 3   default                   NaN                     NaN
# 4   default                   NaN                     NaN
# 5   default                   NaN                     NaN
# 6   default                   NaN                     NaN
# 7   default                   NaN                     NaN
# 8   default                   NaN                     NaN
# 9   default                   NaN                     NaN
#
#                             hangoutLink  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9  https://meet.google.com/tbh-qaus-vtu
#
#                                             htmlLink  ...  \
# 0  https://www.google.com/calendar/event?eid=MDR1...  ...
# 1  https://www.google.com/calendar/event?eid=MDJj...  ...
# 2  https://www.google.com/calendar/event?eid=MzRo...  ...
# 3  https://www.google.com/calendar/event?eid=MDlt...  ...
# 4  https://www.google.com/calendar/event?eid=dG11...  ...
# 5  https://www.google.com/calendar/event?eid=NWdo...  ...
# 6  https://www.google.com/calendar/event?eid=NjUy...  ...
# 7  https://www.google.com/calendar/event?eid=NjBj...  ...
# 8  https://www.google.com/calendar/event?eid=MW5w...  ...
# 9  https://www.google.com/calendar/event?eid=MTdl...  ...
#
#                                            organizer  \
# 0  {'email': 'laura.bernabe.miguel@gmail.com', 's...
# 1    {'email': 'administrator@thedataincubator.com'}
# 2  {'email': 'laura.bernabe.miguel@gmail.com', 's...
# 3         {'email': 'alec.nichols@generalassemb.ly'}
# 4                   {'email': 'jessica@alignhr.net'}
# 5  {'email': 'laura.bernabe.miguel@gmail.com', 's...
# 6  {'email': 'laura.bernabe.miguel@gmail.com', 's...
# 7  {'email': 'laura.bernabe.miguel@gmail.com', 's...
# 8  {'email': 'laura.bernabe.miguel@gmail.com', 's...
# 9                 {'email': 'klellenwood@gmail.com'}
#
#                                    originalStartTime  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  {'dateTime': '2021-05-09T20:00:00-06:00', 'tim...
#
#              recurringEventId  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9  17ejo1onoir2ltconlhq2m3kj6
#
#                                            reminders sequence  \
# 0  {'useDefault': False, 'overrides': [{'method':...        0
# 1                               {'useDefault': True}        0
# 2                               {'useDefault': True}        0
# 3                               {'useDefault': True}        0
# 4                               {'useDefault': True}        0
# 5                               {'useDefault': True}        0
# 6                               {'useDefault': True}        0
# 7                               {'useDefault': True}        0
# 8                               {'useDefault': True}        0
# 9                               {'useDefault': True}        4
#
#                                                start     status  \
# 0                             {'date': '2021-05-06'}  confirmed
# 1          {'dateTime': '2021-05-06T11:00:00-06:00'}  confirmed
# 2          {'dateTime': '2021-05-06T14:30:00-06:00'}  confirmed
# 3          {'dateTime': '2021-05-06T16:30:00-06:00'}  confirmed
# 4          {'dateTime': '2021-05-07T09:15:00-06:00'}  confirmed
# 5          {'dateTime': '2021-05-07T14:00:00-06:00'}  confirmed
# 6          {'dateTime': '2021-05-08T08:00:00-06:00'}  confirmed
# 7          {'dateTime': '2021-05-08T09:00:00-06:00'}  confirmed
# 8          {'dateTime': '2021-05-08T12:00:00-06:00'}  confirmed
# 9  {'dateTime': '2021-05-09T20:00:00-06:00', 'tim...  confirmed
#
#                                             summary  transparency  \
# 0                                  Llega LuisMiguel   transparent
# 1                          TDI Admissions Interview           NaN
# 2                                  2:30 pm Barbara            NaN
# 3  Laura Bernabé SEI Follow-Up Schedule Interview?            NaN
# 4            Laura Bernabe Miguel and Jessica Nerad           NaN
# 5                                        Liam Scott           NaN
# 6                                         refinance           NaN
# 7                                           flights           NaN
# 8                                         Ward's BD           NaN
# 9                                Methin Around Chat           NaN
#
#                     updated
# 0  2021-04-30T23:45:58.472Z
# 1  2021-04-30T17:30:27.361Z
# 2  2021-05-04T19:28:47.578Z
# 3  2021-04-16T03:03:15.487Z
# 4  2021-05-04T19:27:30.164Z
# 5  2021-05-04T19:26:27.467Z
# 6  2021-05-05T19:04:29.934Z
# 7  2021-05-05T19:04:10.771Z
# 8  2021-04-28T22:10:08.251Z
# 9  2021-04-07T00:20:08.165Z
#
# [10 rows x 24 columns]
